# %% [markdown]
# # Disaster Tweets classification using Bidirectional LSTM

# %% [markdown]
# ### Data Acquisition

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/tweets.csv')

# %%
df.head()
# Out:
#    id keyword        location  \
# 0   0  ablaze             NaN
# 1   1  ablaze             NaN
# 2   2  ablaze   New York City
# 3   3  ablaze  Morgantown, WV
# 4   4  ablaze             NaN
#
#                                                 text  target
# 0  Communal violence in Bhainsa, Telangana. "Ston...       1
# 1  Telangana: Section 144 has been imposed in Bha...       1
# 2  Arsonist sets cars ablaze at dealership https:...       1
# 3  Arsonist sets cars ablaze at dealership https:...       1
# 4  "Lord Jesus, your love brings freedom and pard...       0

# %%
df['text'][106]
# Out:
# 'Puerto Rico hit by another 5.9 magnitude aftershock - KYMA https://t.co/P9Th3vpTak'

# %%
df['target'][106]
# Out:
# np.int64(1)

# %%
df.shape
# Out:
# (11370, 5)

# %%
df.isnull().sum()
# Out:
# id             0
# keyword        0
# location    3418
# text           0
# target         0
# dtype: int64

# %%
df = df.drop(['id', 'location'], axis=1)

# %%
df.reset_index(inplace=True)

# %%
df.shape
# Out:
# (11370, 4)

# %%
df.head()
# Out:
#    index keyword                                               text  target
# 0      0  ablaze  Communal violence in Bhainsa, Telangana. "Ston...       1
# 1      1  ablaze  Telangana: Section 144 has been imposed in Bha...       1
# 2      2  ablaze  Arsonist sets cars ablaze at dealership https:...       1
# 3      3  ablaze  Arsonist sets cars ablaze at dealership https:...       1
# 4      4  ablaze  "Lord Jesus, your love brings freedom and pard...       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11370 entries, 0 to 11369
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    11370 non-null  int64
#  1   keyword  11370 non-null  object
#  2   text     11370 non-null  object
#  3   target   11370 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 355.4+ KB

# %%
## Separate Independent Variable
X = df.drop('target', axis=1)

# %%
## separate dependent variable
y = df['target']

# %%
y.value_counts()
# Out:
# target
# 0    9256
# 1    2114
# Name: count, dtype: int64

# %%
sns.countplot(x='target', data=df)
plt.title("Disaster vs Non-Disaster")
plt.show()

# %% [markdown]
# Here We can see that these datas are highly imbalanced.

# %% [markdown]
# ## Data Preprocessing

# %%
from tensorflow.keras.layers import Embedding, Dense, Bidirectional, LSTM, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# %%
## Vocabulary Size
voc_size = 5000

# %%
messages = X.copy()

# %%
messages.head(10)
# Out:
#    index keyword                                               text
# 0      0  ablaze  Communal violence in Bhainsa, Telangana. "Ston...
# 1      1  ablaze  Telangana: Section 144 has been imposed in Bha...
# 2      2  ablaze  Arsonist sets cars ablaze at dealership https:...
# 3      3  ablaze  Arsonist sets cars ablaze at dealership https:...
# 4      4  ablaze  "Lord Jesus, your love brings freedom and pard...
# 5      5  ablaze  If this child was Chinese, this tweet would ha...
# 6      6  ablaze  Several houses have been set ablaze in Ngemsib...
# 7      7  ablaze  Asansol: A BJP office in Salanpur village was ...
# 8      8  ablaze  National Security Minister, Kan Dapaah's side ...
# 9      9  ablaze  This creature who’s soul is no longer clarent ...

# %%
import nltk
import re
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
## Main Logic of Preprocessing
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

corpus=[]
for i in range(0, len(messages)):
  review = re.sub('[^a-zA-Z0-9]', ' ', messages['text'][i])
  review = review.lower()
  review = review.split()

  review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
  review = ' '.join(review)
  corpus.append(review)

# %%
corpus
# Out:
# ['commun violenc bhainsa telangana stone pelt muslim hous hous vehicl set ablaz',
#  'telangana section 144 impos bhainsa januari 13 15 clash erupt two group januari 12 po',
#  'arsonist set car ablaz dealership http co goqvyjbpvi',
#  'arsonist set car ablaz dealership http co 0gl7nucplb http co u1ccbhowh9',
#  'lord jesu love bring freedom pardon fill holi spirit set heart ablaz l http co vltznnpni8',
#  'child chines tweet would gone viral social media would ablaz snl would made racist j',
#  'sever hous set ablaz ngemsibaa villag oku sub divis north west region cameroon http co 99uhgazxy2',
#  'asansol bjp offic salanpur villag set ablaz last night bjp alleg tmc behind incid polic b',
#  'nation secur minist kan dapaah side chic set internet ablaz latest power video http co rhzomqvslj',
#  'creatur soul longer clarent blue ablaz thing carri memori memori http co tbksndrdox',
#  'imag show havoc caus cameroon militari torch hous oku shameless militari report',
#  'social media went banana chuba hubbard announc monday even plan return okstat http co pen',
#  'hausa youth set area offic apapa iganmu local council develop area ablaz okada rider storm lg area offic',
#  'mamatabanerje polit violenc amp vandal continu unab west bengal offic asanol',
#  'amen set whole system ablaz man http co j08xhdcgbd',
#  'imag show havoc caus cameroon militari torch hous oku shameless militari http co giwzch533d',
#  'cow today local factori sadli still ablaz redjanuary2020 http co cmyukzrckz',
#  'rengoku set heart ablaz p miss style color c http co yruf9g68s0',
#  'paulzizkaphoto rundl ablaz wish good even http co d0nlme1hqz http co hlvlt6qiip',
#  'french cameroun set hous ablaz ndu roast two young boy home target kill genocideins',
#  'cameroon bir soldier 05 01 2020 invad southerncameroon villag kimar set ablaz total',
#  'fire ablaz throughout land prophos apocalyps come fruition build stand come st',
#  'thankfultuesday isaiah 43 2 pass water pass r http co jep3l1ou36',
#  'walk fire scorch flame set ablaz product',
#  'origin intend fire boarder oppos ship crew gunner ship riggi http co z5vpwuybcl',
#  'warm greet occas lohri winter pass may everyon woe troubl set ablaz',
#  'anoth arson njikom boyo nwr ambazombi yesterday 13 1 2020 set ablaz council build countri wo',
#  'anoth public market haiti mysteri set ablaz independ merchant overwhelmingli women becom',
#  'kind true sadli',
#  'swear jam set world ablaz',
#  'marivan kurdistan provinc monday jan 13th 2020 protest set propaganda banner qassemsoleimani ablaz',
#  'marivan kurdistan provinc monday jan 13th 2020 protest set propaganda banner qassemsoleimani ablaz http co ivgcyjzlmk',
#  'turn blind eye icid set ablaz 50 hous h http co ud84oqxg9k',
#  'love complet crazi fuck dream rip like torn jean ev http co gcvyw5ezkb',
#  'term demon burn dark ruin peopl cannot use magic interact without harm ac http co zedawofuu4',
#  'heartfelt appreci prime minist yab tun dr wife yabhg tun dr siti hasmah mohd ali fo http co yowup1byup',
#  'watch former cm akhilesh yadav went meet injur kannauj accid hospit chhibramau ask emerg med',
#  'gave us everyth horribl foot infect wore one thong http co ma9sfl6shw',
#  'yeah new swag point 100 sinc accid like total transform bob',
#  'cool day git push origin current branch name know http co mr0yagewqj',
#  'preorder newreleas today 12 wit connect investig thenutcrackerconspiraci die either',
#  'back neck still fuck accid',
#  'rt princ harri confirm mother princess diana death accid http co 1ade3uz3',
#  'note democrat muslim ban islam race soleimani terrorist amp extermin assa',
#  'juwan johnson oregon one big dude look like tight end stuck receiv group accid',
#  'appear man upsid face new year eve parti air forc base 1943 man',
#  'speed car ram group peopl return attend templ festiv ayyappan kavu thum',
#  'friend armi lost father accid mom right still unconsci pleas pray mo',
#  'mlindo vocalist anoth car accid http co bxr9regak6',
#  'greater treasur highest human qualiti compass courag hope even tragic accid',
#  'pleas help friend non fault accid result vehicl writt',
#  'hurt younger sibl accid http co damteoqtzu',
#  'david cameron decis hold referendum express medium road traffic accid http co xatyhftxoa',
#  'auto accid injuri set process motion get complic find long take settl http co gqp5tv03df',
#  'one right call babi accid jd call bless use loveliest word describ',
#  'actual post accid twitter decid stay',
#  'question let say happili marri husband die tragic accid devestst pussi',
#  'kampala metropolitan east custodi two suspect allegedli strangl death passeng http co 9v77vm51vw',
#  'complet avail public inform fire mostli start human purpos accid th',
#  'phd colleagu went way bulli caus work discomfort http co g3hivxzo8t',
#  'speed car ram group peopl return attend templ festiv ayyappan ka http co e3bblavdda',
#  '6yr old bella need new home due incid accid live older kid right ho',
#  'look shit need littl ass whoop hit somebodi accid lecheminduroi bransoncognac starzg',
#  'accid earth god divin craft masterpiec design destini v http co kfc7tpwuj6',
#  'iran say shot ukrain intern flight 172 accid pictur aircraft http co codnyq77uz',
#  'saw truck contain almost fall morn report',
#  'judg less smile oldest profess accid lol',
#  'puerto rico hit anoth 5 9 magnitud aftershock kyma http co sf2wbvd5me',
#  '3 6 aftershock 4 05 asleep movement bed woke scari wish http co la2mwclxhf',
#  'good night friend per usg new 5 9 quak morn caus 7 day aftershock forecast chang',
#  'yea wasnt long kill like 6 7 second sure would http co pexyxyjofm',
#  'honor essay aftershock mark 50th anniversari alvin toffler futur shock compendium essay',
#  'ticket sale aftershock http co kqhmzbgmvk nowplay k4hdradio',
#  'come us aftershock',
#  'think felt aftershock',
#  'quick comparison ongo 2020 m6 4 puerto rico earthquak sequenc 2003 m6 5 central california sequenc',
#  'puerto rican refus go home asid 5 4 aftershock ground southwest puerto rico',
#  '2010 incept social network easi black swan toy stori 3 kid right aftershock',
#  'puerto rico hit anoth 5 9 magnitud aftershock kyma http co rrtntma8nr',
#  'puerto rico hit anoth 5 9 magnitud aftershock kyma http co ww3cdsvdv2',
#  'hard hit http co x3e2mf6dko',
#  'musharaf verdict mild aftershock extens one worri come extent',
#  'puerto rico hit anoth 5 9 magnitud aftershock kyma http co vradkszaln',
#  'kumera yellow aftershock ph19fossil featur bankbtn good live magazin photographi stylist shino http co v9lj65ttzr',
#  'puerto rico hit anoth 5 9 magnitud aftershock kyma http co mmxxzwbpaf',
#  'pleas pray puertorico http co uwqp2ynohw',
#  'puerto rico hit anoth 5 9 magnitud aftershock kyma http co lrtllbb9tv',
#  'yakov z http co blgyunumdg',
#  'darkak 7 yeek possessor kill possess aftershock ritch tunnel 2 http co azoizicsd',
#  'check latest video superzero vol 1 closer look http co t36kgxjdvi closer look superzero vol 1',
#  'might small aftershock feel anyth',
#  'stay inform stay engag what go puertorico earthquak usg 30 day aftershock http co byibfplhyg',
#  'isnt good feel peopl puerto rico http co gzc7tyrox',
#  'aftershock vapor 15 pro review aussi aussi aussi http co pwnq3var2r powerupau',
#  'puerto rico worker explain earthquak aftershock plead go viral http co hhfjqnlet8 via',
#  'unfathom number live larg earthquak slept tabl one terribl night',
#  'nah need calm http co eokphshn5r',
#  'think some1 spat blood marilyn manson set aftershock',
#  'two quak magnitud cannot say one preshock aftershock one obv',
#  'm4 m5 aftershock happen within 15 day m5 m6 main shock predict say',
#  'think silivri m4 8 aftershock silivri m5 7 month ago quak professor alway say nonsen',
#  'think aftershock lyric beat brent never recov',
#  'apex separ monarch separ well theori mechagod http co abzdkqocpv',
#  'think some1 spat blood marilyn manson set aftershock',
#  'send mate simon bar ask guiness end carlsberg export mint',
#  'usg earthquak expert puertorico instal temporari seismomet help track seismic event includ jan 7',
#  'puerto rico hit anoth 5 9 magnitud aftershock kyma http co p9th3vptak',
#  'weekend puerto rico struck 5 9 aftershock caus damag home school leav thou',
#  'could leav gave',
#  'full experi start one 1st seri food run low save young governor',
#  'magnitud 5 9 quak puertorico morn caus 7 day aftershock forecast chang estim increas',
#  'continu updat 30 day aftershock forecast scenario puertorico forecast post english http co',
#  'anoth 6 0 aftershock hit puerto rico last night peopl cannot go home even one po',
#  'aftershock comic prefer work partnership creator build team ground',
#  'earthquak aftershock mess power',
#  'aftershock forecast puerto rico',
#  'like iran shoot airplan accid',
#  'bing bong airplan accid remix',
#  'morgan surpris see shaun back work alreadi offer condol dad shaun say airplan http co sxwrba7hj5',
#  'load rubbish never immin threat jesu christ iran sho http co c815dfzf7c',
#  'actual block internet accid know like iran shot ukrainian airplan',
#  'conclus 8 previou page incorrect imho wit observ streak light http co tz4xv7uxcw',
#  'celebr iran sadli compatriot kill down uk airplan di http co ctjvwich2v',
#  'iranian radar cannot tell differ incom missil go ukrainian airplan http co hoeejeuih',
#  'look timelin see hate coun http co 30cmq9gspj',
#  'militari mistak 1988 us militari shot iranian passeng airplan 2020 iranian militari shot ukr http co 177gbnqiht',
#  'secret anti spi servic middl east high alert demolit commerci airplan u',
#  'friend live believ basic right know happen http co 49nbxhutfp',
#  'secret anti spi servic middl east high alert demolit commerci airpl http co 9pzvifdpkv',
#  'iran fire 12 20 surfac surfac missil fire surfac air missil http co mpkttfcafb',
#  'basic kill gener put whole countri confus statu shoot civ http co p1lkrqhp1i',
#  'refer shoot airplan realli',
#  'refer shoot airplan http co xkvqrdtjhr',
#  'anyon believ incid accid idiot airplan approx 3000 fee',
#  'anyon believ incid accid idiot airplan approx 3000 http co axt3omjme1',
#  'iran blow airplan accid intend shot accid civilian aircraft',
#  'airplan accid',
#  'mr u hold p trump account airplan accid r sad pl tweet abo http co cqsmfvtlmw',
#  'dial 112 toll free phone event wish report fire flood theft arm robberi kidnap',
#  'dial 112 toll free phone event wish report fire flood theft arm robberi k http co 1e2jgi6c8q',
#  'iran shoot commerci airplan claim accid anyon realli believ',
#  'may unawar cnd current mourn 57 canadian down airplan accid iran flag',
#  'sorri loss iran never shot airplan sky accid say',
#  'iranian knew takeoff happen amp knew airplan manufactur american http co 9jnbfb0zwh',
#  'mass anti govern protest erupt iran leader admit shoot airlin still cannot believ w http co dwexwdlbgn',
#  'read whole thread blame trump iran shoot ai http co evl7sdnw0z',
#  'airplan accid answer us design iranian govern terrorist ha http co 7a2ogpyniq',
#  'hey got swamp land sale either naiv plain stupid iran down http co fu3cjjf1q8',
#  'perhap prod other zelenski decid ukrain noth lose pile onto iran never seen mani op http co bvzj33dzep',
#  'canadian concern airplan shot accid 67 canadian mani iranian',
#  'shoot airplan accid bullshit like accident shoot firearm especi sinc http co xkeyvgxfiq',
#  'odd iranian accident blew airplan take someon play http co y2yx1gz6hq',
#  'canadian concern airplan shot accid 67 canadian mani http co v8mskmrlyb',
#  'excus shoot commerci airplan innoc civilian oh sorri jeremi say',
#  'beat respons track airplan surfac air missil',
#  'unimagin 174 peopl gone one accid could anyon point surfac air missil http co 7abwo7hxuz',
#  'accid iran rocket airplan kill 180 peopl lib defend like ok b',
#  'excus shoot commerci airplan innoc civilian oh sorri jeremi say http co gukc4toutn',
#  'well let see know far bodi count demonstr http co sppcskbuq0',
#  'beat respons track airplan surfac air missi http co rfywvnqo2z',
#  'good lord yeah accid airplan give missil right away',
#  'iranian leadership down commerci airplan purpos kid say accid',
#  'ooh look nyt becam lawyer iranian regim stupid newspap time vi http co sbfucnkmpr',
#  'exactli one accident fire rocket airplan leav countri airport http co lqdfg1thtn',
#  'say shoot airplan w innoc ppl accid bruh',
#  '6 nuclear physicist airplan accid',
#  'murder friend shoot airplan accid kill around 200 innoc peopl wa http co i3w3gdnksx',
#  'yup us shot iranian airplan accid supp http co smtor2tsjn',
#  'unit state down iranian terrorist world press dedic ton articl life live ira',
#  'besid airplan shot accid thing habben also high level pro iran militi',
#  'cbc news said oper missil launcher shot airplan cockpit taken http co uy2yyaqear',
#  'consid gt person video camera know record attack indic',
#  'besid airplan shot accid thing habben also high level pro ir http co oljmmb1tj9',
#  'yeah yer well prepar hit build amp knock yer airplan accid better keep http co ww1w8loyvl',
#  'shoot plane accid human error iranian shoot mi http co jesxuykyvd',
#  'attack n airplan taken accid iran want world know co http co 2mimawnc6x',
#  'grover airplan accid doctor',
#  'trump accid crash airplan ukrain main factor power person world whose count',
#  'trump accid crash airplan ukrain main factor power person world whose http co mskujje79x',
#  'although late extend condol famili victim ukrainian airplan fall inclu',
#  'iranian militari admit shot ukrainian airplan missil accident accid crim',
#  'much talk ukrain airplan within iran usa conflict conflict wise irrelev mo http co lpe4tm3pyk',
#  'although late extend condol famili victim ukrainian airplan fall http co hbaxnwmvoz',
#  'iran shot airplan full innoc peopl say want trump appropri r http co dedr4ynzk9',
#  'still silent kill 176 innoc peopl iran iranian militari admit shot ukrainian',
#  'iranian chose day time send missil insid iraq also control http co ehjp8cnlw4',
#  'airplan routin flight path airport one would think shot would fam',
#  'germani foreign minist heiko maa say must assum airplan crash iran terribl accid http',
#  'compass famili ukrainian airplan shot accid',
#  'compass famili ukrainian airplan shot accid',
#  'fire engulf ambul convey corps cathol priest mother streetjourn http co gk6dagkrrl',
#  'racist concern correct 50 000 resid birmingham speak english birmingham england',
#  'waarland ambul p2000 a2 10187 rit 6026 sabinahof waarland http co yeszazbodp',
#  'usdjpi despit richter scale overbought fxstreet line swissquot bullish long jason sen mr ambul chaser b',
#  'usdjpi despit richter scale overbought fxstreet line swissquot bullish long jason sen mr ambul cha http co ivuuacsq54',
#  'untam boy sing love siren ambul theuntamedboysinbkk http co 2hkshths8w',
#  'pull ambul',
#  'hope go ambul wait bottom way fat lump cli http co eq0fg2fo7i',
#  'ambul cover come theuntamedboy ambassador thai spring festiv 2020 delight',
#  'drive drunk choos way come back home taxi b http co bk3xokgfkq',
#  'yer sever ambul ramp fund resourc http co kpenm6wiej',
#  'zulaykha son ambul driver kill suicid attack maimana faryab everyday visit ambu',
#  'first taken damn hospit man die walmart ambul outsid focus',
#  'jinu okay hit head faint rememb anyth yoon ambul ride hospi',
#  'come recent fuel stolen ambul vehicl damag staff car whilst ambulanc',
#  'gone ambul chase australia',
#  'drumrol beach girl henri tri keep pressur wound call http co gvo4m76b1o',
#  'racism absolut delight http co wcp0oyzjvi',
#  'noroviru like detox get crap system much like flush central h http co mwjbxcelyw',
#  'ooh guy know gauteng peopl go studi nurs ambul nurs keep aliv transit',
#  'iranprotest tehran right valiasr intersect special forc head paradis ambul',
#  'one silent pray unknown ambul pass http co 23zs7qjtdg',
#  'long night mom sugar drop 28 dad call ambul fun hospit late shift',
#  'noroviru place like home winter bug unpleas usual goe away coupl http co aigerm2h2m',
#  'understand jongkook danc like breath heavili end sequenc lyi http co dt4rpzyxs7',
#  'unilorin oxygen whole univers ilorin oxygen refer us uith think mayb',
#  'ambul nurs',
#  'angel africa netcar 911 air ambul doctor paramed activ inter hospit tran',
#  'ambul need call us today toll free number 0819696 http co awzjw2wxkx',
#  'love messag receiv thank much',
#  'time action accid save someon life find someon injuri call ambul http co 9pptijujpn',
#  'technic brain speak rage debat mostli disposit amp knowledg calm storm even http co vdnc9tkxdb',
#  'got back hospit bc accident blend finger cook promis ambul doctor w',
#  'anoth race bait ambul chaser expos racism action peop http co 2uhepawvk9',
#  'ooh guy know gauteng peopl go studi nurs ambul nurs keep aliv http co m6yk1fiblu',
#  'nicki minaj singl handedli annihil male speci day drop',
#  'must annihil',
#  'basic let peopl work hard money save invest wise snatch fu http co rkejh1oqs7',
#  'thank offenc taken realli choic centr left parti either http co w0rdsfc7jp',
#  'commonest line naija song becom annoy way whyne e dey blow mind pleas',
#  'quran vers leader choos qasem soleimani uniqu moment soldier islam tirelessli foug',
#  'wrong way aca pass http co 8hszxg6eic',
#  'get readi pick weapon choic chose lute cours think everyth http co 3gi3quvh5w',
#  'actual imposs tell whether dan bori less across brief journalist almost journalist http co 4cg1xr6dqn',
#  'zero chanc candid win next elect delud hard left http co xnurp3teng',
#  'good riddanc bad rubbish like say annihil fedelection2020',
#  'like understood yet sh1t polici plu touch http co w2jxhydwzk',
#  'breast perish name bottl poison make want cri make want http co 4l31qgatac',
#  'http co ebf9qbes8i beauti delic tender vampir taejin annihil tonight http co pciytuftlj',
#  'reminisc time annihil pb made look easi 117 5kg feel fiin bring gpc http co zpo8jagq7v',
#  'titan rais trident drink victori annihil enemi yesterday sent hade',
#  'promis perish name almond make want cri make want curs de http co zularoqepo',
#  'sne realli tryna see get annihil dm psn bro',
#  'titan rais trident drink victori annihil enemi yesterday sent hade http co d4u6lykaxv',
#  'appreci bbc igbo start expos britain partook biafra genocid 4 millio',
#  'poll mean shit hugh wrong massiv effect 3 vote leav http co eptuvm6j5q',
#  'pier morgan annihil simpl logic http co rclwbc7f9l',
#  'pier morgan annihil simpl logic vegan advocaci good morn britain http co rclwbc7f9l',
#  'pier morgan annihil simpl logic vegan advocaci http co rclwbc7f9l',
#  'appl perish name adderal pill make want cri make want cur http co aewjnrzc7b',
#  'win feder judg lift tro build floodplain chang game judg absolut',
#  'oppenheim annihil done referenc mistress death dislik thano http co 165ot51jx',
#  'lost 4 big team event 2 point 80 pretti nice list like annihil insid',
#  'get annihil 01 miami http co b8loc0ura',
#  'alli us mean annihil minut look kurd',
#  'pore nose get annihil finger 2am http co ydkde1rs3t',
#  'moment doc ock spidey bodi realiz spidey hold back fight time pete',
#  'best way describ current emot state toddler wave pool fine part get annihil w',
#  'nicki minaj singl handedli annihil male speci day drop http co v7kk4pwdtk',
#  'answer 4 soooooo happi renew season ticket would lost mind di http co dspkjkhw96',
#  'machin chang music pretti much annihil concept live band play real instrument howev machin n',
#  'lsu would annihil ohio state univers even domin wisconsin http co ynyvuizo0t',
#  'mention 2013 florida state team well annihil everybodi play except auburn http co s3y2nzcxol',
#  'machin chang music pretti much annihil concept live band play real instrument howev machi http co wxgfpzboit',
#  'get absolut annihil hook tarkov',
#  'disney amp psych rey lo wonder upset w star war http co uh4zsqa5e3',
#  'thot statu annihil',
#  'presid trump great presid annihil terrorist risk inti http co bfqo0vrr0z',
#  'think would learn clinton get annihil http co iglk8q8mb9',
#  'antichrist singl handedli annihil american movi industri',
#  'auspol onto theliarfromtheshir manipul elect http co zg16zu0mf9',
#  'devast thorough refut ned flander stream annihil orthodox straw men',
#  'devast thorough refut ned flander stream annihil orthodox http co 8xlx0crbua',
#  'mayb current think relat upcom titl stori arc x factor tonal feel http co kjj5nn7fgo',
#  'annihil 25 graduat broad made call gaud snatch soul bust http co sdrpov2vfi',
#  'thot statu annihil',
#  'guy annihil best defens colleg footbal lose two game sick',
#  'broke destroy annihil shatter ankl abou never',
#  'clown photo left far left joke predat drone strike fake news corespond dinner c http co m410myh6l5',
#  'lsu best team countri start finish season annihil oklahoma semifin http co itvqnjnyzv',
#  'valid total bodi work matter lsu prove worthi 1 seed http co ghzkzc7blw',
#  'els perish remain still continu els remain annihil',
#  'berni sander coddl politician today get annihil win nomin',
#  '1 iran govern domin headlin crush cruel islam regim purveyor proxi war state sponsor ter',
#  'lot talk violenc carri name hindu cow vigilant lynch extrem http co trq3kblix8',
#  '5 x us navi e 6b airborn probabl noth immin global annihil http co t7ilcjvh7o',
#  'deflect issu discourag statist bengali hindu f http co rgjknxyzl8',
#  'want u like annihil',
#  'love hate uncutgem like sever movi recent evok clockwork orang grotesqu compel http co kphucerwci',
#  'surajm bhau somehow forg allianc would hv result annihil ummah',
#  'annihil http co r806oq6eaq',
#  'au vic bushfir appeal doggo anim farm tomb annihil http co sgknedtlto',
#  'au vic bushfir appeal doggo anim farm tomb annihil http co sgknedtlto',
#  'anyon know offici site oppos total annihil south africa new health system reform',
#  'two alien race go war earth caught middl http co iklfxk1sek',
#  'strangest part palpabl disappoint longer reli public fund year auster',
#  'like iran iraq war root mutual annihil http co x5gv676ney',
#  'need polit autonomi noth less prevent demograph annihil',
#  'terribl high elf shortsword annihil',
#  'simpl arab reject hand 1947 un partit plan instead wage war http co gauqyo8bw2',
#  'russia blame trump iran strike impeach trump annihil iranian gener present decen',
#  'complet nuclear annihil except pop back happen',
#  'know movi oscar year annihil',
#  'annihil http co 3qhiwn016i',
#  'biggest fs chat 2019 film twitter fake cat trailer w annihil score dub',
#  '99 nexu araphym darken part 3 horror paranorm ebook novelett e h jame thing stand',
#  'die salvat dedic capitul annihil papal commend reincarn heaven http co h65k0kk0vm',
#  'watch thing scam wick 8949 99 realli start parti annihil',
#  '99 nexu araphym darken part 3 horror paranorm ebook novelett e h jame thing http co x1frq0gdol',
#  'http co ycudyincz8 data assimil agent base model use creation annihil oper http co kyqnzczdkj',
#  'happi see peopl regain conscienc afteral soul stand watch http co ruqutjicx1',
#  'new annihil ft tragedi khadafi p sway amp grand surgeon djkool real king trap vol 11 h',
#  'annihil one fav',
#  'start annihil rn first time somehow',
#  'need surviv practic faith think hindu genocid http co xq3zy7y7op',
#  'also need surviv practic faith think hindu gen http co ozlw4p5nwv',
#  'speak atroc annihil christian across middl east commit muslim daili sat',
#  'yeah surpris heard first anoth gem electron score http co ttfhyc2neo',
#  'understand system oppress cost oppress total complet anni http co rgqeyk2z7b',
#  'dont get bia flip short annihil incom',
#  'annihil hulu',
#  'cannot yet see danger lurk hasten annihil n http co me03jall2',
#  'weekend drove burn landscap big bag sweet potato roo severit',
#  'amount sci fi media could prepar aspect climat apocalyps http co pv6spn1r9l',
#  'four horsemen apocalyps http co wey8juste6',
#  'two day long two day done http co ar09iwu0fz stage 3 bravo free ki',
#  'never understand smell girl perfum last 8 sec meanwhil boy go apocalyps st',
#  'apocalyps happen want armi follow team everyon heeli hundr',
#  'amount sci fi media could prepar aspect climat apocalyps',
#  'eskenfilm kauft einen ford falcon und viel sprit die apocalyps kommt ohn tempolimit http co rycjulqk4p',
#  'euroleagu bet365 8 unit http co btn3kliumb',
#  'apocalyps come http co nvvvdtxrxo',
#  'like review apocalypsecow http co jhcxbfxsgx fair monbiot view http co cxpzqclkdf',
#  'ancient vike runeston warn ragnarok apocalyps predict extrem climat chang http co wchvcblboe',
#  'also made think life basic like calm foreground inferno horizon peopl w',
#  'realli nice night outsid moment expect four rider apocalyps arriv http',
#  'apocalyps',
#  'http co 6vsh3kdagn',
#  'yea let honest kid valu pretti much game see roblox play whatev f http co k0ycbknn9u',
#  'veganuari tri one v burger today pick falafel burger lettuc pickl sla http co e9xr0fkhkz',
#  'franci ford coppola denni hopper set apocalyps http co qthyvhbj4p',
#  'late think miriam rose ungunmerr baumann gerard manley hopkin tell',
#  'common sens twitter first sign apocalyps look great',
#  'imag bibliqu apocalyps 21 3 4 lechrist leseigneur autorit j suschrist dieu lar demption http co izb3xwotu5',
#  'jam set son carter usm 30 someth jimmi page outrid nirvana nevermind gun n rose appetit http co 5gnaptmu0t',
#  '4 32 1 pand mie apocalyps soupir http co wsqrchgdhb',
#  'chodzi ci apocalyps',
#  'prophesi jesu savior44 prophesi say sign time apocalyps like th http co fizpzykjt9',
#  'apocalyps chic',
#  'join chum month improvis apocalyps movi would like see world e http co zcsagvfuht',
#  'import notic global warm apocalyps schedul 2020 postpon meme polit http co igtzxahzag',
#  'texsch liter caus apocalyps invalid',
#  'marcelito pomoy nakaka proud http co rzi6gd3mpm',
#  'inbefor xenobota caus apocalyps http co fkhuqeiox',
#  'go place zombi apocalyps happen',
#  'damn final dreamt real apocalyps short dream half dream came rea http co cgb5qgptmk',
#  'thrill amus read british fantasi societi game changer apocalyps author mark kirkb',
#  'surviv london rush hour tube ride basic like surviv zombi apocalyps http co oc1wthjxiw',
#  'gta 5 zombi apocalyps mod 2 surviv gta 5 mod http co jwrjlhmw6r',
#  'gta 5 zombi apocalyps mod 1 begin end gta 5 mod http co j8kxz6sxdn',
#  'wear zombi apocalyps zombi surviv guid http co bbn6ceum3n',
#  'day 9 post apocalypt lanc realli want share everyth best buddi apocalyps mean hard time',
#  'rememb said creat god imag think us creat often biblic apocalyps',
#  'apocalyps deathknight worldofwarcraft http co gfbi8wfxvo',
#  'greta thunberg pleas phjoto dont want fjamou want save small windmil town frjom climjat apo',
#  'armageddon wheeli bin',
#  'arm armageddon part freez',
#  'disgust word good reason separ church state pro',
#  'new music dj joenel feat ajebo hustler dr barz amp dan dizzi armageddon http co s8bauopzdz http co jiel4vwu1f',
#  'new music dj joenel feat ajebo hustler dr barz amp dan dizzi armageddon http co rlociexqpt http co 2dczbrs1nj',
#  'white saw trump ride golden hors alongsid jesu armageddon claim expert jesu',
#  'pitch black 9 30am mallacoota 4 000 peopl fled australianfir seek shelter beac',
#  'kind insan separ church amp state word level crazi prove',
#  'pitch black 9 30am mallacoota 4 000 peopl fled australianfir seek shelter b http co ytsauns5j8',
#  'saw trump ride golden hors alongsid jesu armageddon snort look attent',
#  'true jesu usual ride harley armageddon picknick http co luyrj6ny7z',
#  'getter robo armageddon 1998 http co fqd7eobjq8',
#  'white saw trump ride golden hors alongsid jesu armageddon busi standard news http co 4wyxf8dr78',
#  '65rt 270 thank',
#  'grew 70 ryouma love much also love armageddon ryouma new getter ryouma http co 15m5mg8tcp',
#  'ever thought make anoth spawn game like spawn armageddon back day',
#  'glad go make domest flight cheaper everyon increas amount co2 air http co 07pwcjiulm',
#  'say see armageddon soon certainli hope sure could use vacat stupid shit',
#  'music dj joenel armageddon ft ajebo hustler dr barz amp dan dizzi http co w9vtubqho',
#  'chose one 9 bush 2 cheney puppet trump penc putin pompeo http co kecqsfmjei',
#  'white saw trump ride golden hors alongsid jesu armageddon http co og3rkpyvh8',
#  'hold wealth power privileg due defect money system humani http co epmdxarau',
#  'white saw trump ride golden hors alongsid jesu armageddon http co gfflp3ynk3',
#  'reason jesu would ride along side trump would show gate hell w http co 0qlg3g8yko',
#  'sound strikingli similar worm armageddon cd',
#  'chick clearli need glass saw golden hors ass walk jesu armageddon',
#  'stori caught eye davind singh saga get curious curious deep state much answ',
#  'armi challeng name 5 bt song top head separ forget repli use boywithl',
#  'armi privileg abl call album sold 4m copi flop think that beauti',
#  'batch 2 donat armi second batch donat alreadi given philippin red cross ha',
#  'today pak armi soldier b thank indian armi indian armi carri deadli strike neelum vall',
#  'even imagin chao armi twitter bt member announc suddenli get marri',
#  'armi tire also armi wait 6pm kst get someth later sure btsarmi b',
#  'armi challeng 500 retweet 200 repli vote btsarmi bestfanarmi iheartaward',
#  'wevers offici bt suga 200110 armi zip bt cinema interview amp galleri perfect man actor suga http',
#  'wevers offici special gift armi bt jimin http co xqollquut',
#  'jama masjid pak judg rebuk cop bhim armi case http co v3wdkphvq0 ndtvnewsbeep bhimarmi http co',
#  'peopl armi kill peopl everyday get sent home jail time',
#  'get armi card premium http co lamdjmk7n7',
#  '75 repli 4 minut armi boywithluv bestmusicvideo iheartaward',
#  'max talk fan amp jungkook sing song mention armi send flower http',
#  'wevers offici bt v armi zip bt cinema movi poster neo noir fill unexpect plot twist shocki',
#  '2020 iheartradio music award rt 1 best fan armi btsarmi bestfanarmi iheartaward',
#  'taehyung armi zip photo drop later tangenaaaaa ughhhh http co g1r9tmwlxj',
#  'forc develop local made missil fire apach helicopt obama halt sale israel 2014 israel',
#  'rememb armi use googl translat ask excit go korea mess said horn',
#  'j hope chicken noodl soup feat becki g mv pass 130 million view iheartsaward bestfanarmi',
#  'armi zip drop connect bt run damn',
#  'new brother suga http co rqm9zhwspi',
#  'rememb armi room full bt univers theori http co rwmwlpzel7',
#  'want remind still think armi made say jungkook meet',
#  'v wevers armi everyon pleas help philippin armi v heart ach nowaday hope nobodi',
#  'one wrote post wevers glad mani armi abl see awar wh',
#  'armi id two paratroop kill roadsid bomb afghanistan http co eug1zoy1lj http co lujcwmutcd',
#  'shazam import ph armi feel free dm us question teamw',
#  'avalanch hit armi amp bsf post 4 jawan rescu 1 jawan still miss bad weather hamper rescu oper http',
#  'wevers offici special gift armi bt suga http co 7vqdvghgfj',
#  'taehyung armi zip photo one hour dunno surviv',
#  'video groom philippin danc medley song friend wed new br',
#  'rememb yoongi repli armi english read tini english voic devast',
#  'armi year bighit acquir',
#  'armi detect found bighit creat websit connect bt yet confim link web',
#  'indonesia armi huge pleas vote boywithluv bestmusicvideo iheartaward',
#  'groom philippin decid give wife armi kpop fan medli bt song honestli',
#  'pre order untuk map soul 7 oleh armi china telah mencapai 230 192 copi gilee gilee bestfanarmi btsarmi',
#  'taehyung armi zip photo come today absolut shit http co qatajvlkui',
#  'nw still funniest sht ever http co jcxknn6iti',
#  'abbott green armi vision http co 1onh29zoq5',
#  'wevers offici special gift armi bt v http co ga43lvrqdl',
#  'tell u also give militari name http co hjmsl2kdae',
#  'one man armi thala ajith 19yearsofdheena',
#  'two gender emascul liter armi',
#  'media cosmopolitan philippin wrote articl taehyung send prayer affect',
#  'decid tonight love forev armi forev',
#  'latest updat pre order map soul 7 china armi reach 230 192 copi via baidu tieba',
#  'viciou nasti vindict abus digit armi launch twitter attack satyanadella yet mi',
#  'babi armi experi outcast bc honestli one best time armi twitter everi singl day',
#  'find ph armi find ph armi find ph armi find ph armi find ph armi find ph armi',
#  'wevers offici bt jimin 200113 armi zip bt cinema interview amp galleri young forev mono actor',
#  'brutal provoc statement dgispr alreadi butcher butcher forc',
#  'congratul j hope 130m view cn let stream much hobi bir',
#  'matter bt amp armi rm mention abt http co ljdifdz0bi',
#  'whenev surgic strike happen believ armi stand even pm statement keep ask e',
#  '200114 armi everyon help philippin armi pleas prayforthephilippin v heart hurt lot plea',
#  'latest bloodshot trailer vin diesel rebel armi super soldier via http co au',
#  'connect armi iheartaward btsarmi bestfanarmi http co ffrunz8dvp',
#  'berni warren two progress presidenti candid gener remind',
#  'firefight let jail despit seriou sex offens arrest start 17 fire australia http co gimhyilwgc',
#  'australia sinc 1910 one imag say arson ass total denier bollock australianbushfiredisast',
#  'funni australian author investig nearli 200 peopl arson alreadi charg http co 6mat9myxga',
#  'interest post caustic tweet fail morrison govern paulin hanson newspol came',
#  'pleas least tri research first speak light human start aussi fire',
#  'believ credibl current inform arsonist http co 5aunr5kvev',
#  'climat chang arson jihad http co bnylrjsacj look behind australian wildfir',
#  '13 yr old imagin jnu student burn us flag 3 yale student 1 xtian amp 2 muslm name ch',
#  '1 per cent land burnt nsw bushfir season offici attribu http co prcxhhyt1b',
#  'arson bastardri co ordin global green scheme convinc world co2 caus global warm',
#  'know hon judg get carri away stuck law one den http co gwdfjdcsan',
#  'arson failur enact control burn easi',
#  'viral fals claim nearli 200 arsonist behind australia fire explain http co v8mjffmbph hanniti',
#  'plain hard fact australia alway fire toni heller http co psfw3bhioq',
#  '190 peopl arrest arson',
#  'number messag say media ignor arson major caus australia bushfir crisi',
#  'newscorp dig deeper advers public coverag bushfir insist concentr arson backbur',
#  'inquiri show alarm increas numb',
#  'climat chang 1 caus arson perhap arson 1 caus climatechang whatev sol',
#  'two recent studi say 52 000 54 000 bushfir australia everi year',
#  'still wait scientif data support arson rate increas',
#  'ilhan world arson climat chang',
#  '2009 bushfir victoria 173 fatal labor govt amp kevin rudd caus arson power line lightn nobodi',
#  'boat fire pa small boat harbour arson suspect http co k7hghdjltq via',
#  'inquiri show alarm increas n http co van8gf8cx3',
#  'polic figur show far fewer peopl australia charg bushfir arson http co 8kpmnfsmcp http co vqezhecrjm',
#  'map 379k tweet 190k account au bushfir arson narr arsonist climat chang re',
#  'rubbish hillari australian live near fire amp caus fire 1 arson approx 200',
#  'cannot stop bushfir must plan live mean signific chang includ inform http co xx4qcfv9h3',
#  'emerg servic commission andrew crisp say victorian fire start lighten awar polic',
#  'guy next text peopl arson fact file bushfir conspiraci theori',
#  'gotten lot hate mail latest articl actual arson figur bushfir season accu',
#  'know fact said lightn arson predominantli respons start season',
#  'right im rdg cast heaven surpris one thought arson',
#  'ummah everyth emin intellectu readi make ridicul claim provid cover foo',
#  'yeah arson poor forest manag climat chang',
#  '200 peopl arrest arson',
#  'offici charg nearli 200 arson loot wildfir rage http co sy2lhghsgz',
#  'theori fact earth end sinc last time al gore democrat amp climat chang advoc',
#  'fire chief nsw made clear may case arson fire caus ligh http co 7gdltmgvro',
#  'chichest man convict arson assault http co hsqftj8xfu',
#  'lack decent land manag strategi fire prevent http co iekcfnpzv',
#  'ladi ever go jail arson dusti ass cheat man c class date sittin waitin',
#  'arson start fire though ar http co n6keljk9yb',
#  'john brennan sack corrupt ex cia director one peopl http co 7ylzhd8vo6',
#  'part analysi misinform propag australian bushfir produc detai',
#  'tasa member et al recent bushfir bot arson claim au',
#  'fuck heart littl rainbow embroid onto pant im go commit arson http co hf30tdqgpi',
#  'burn noth jon moxley final get match commit arson heheh wa http co xrsenysli6',
#  'violenc arson across west bengal striker tri enforc bandh 55 arrest kolkata time india http co bimdumdstt',
#  'arson climat chang arson climat chang arson climat chang arson climat chang arson',
#  'doubt offici downplay arson role australia fire global',
#  'dr ji pakistan bangladesh terrorist element behind anti caa arson say dr swami dr swami claim',
#  'arson major factor australian fire http co x59fykaoda',
#  'anti caa protest prof robin verma releas lucknow jail morn illeg detain brutal tortur',
#  'respons spread misinform arson behind horrif bushfir season australia',
#  'actual claim 200 peopl hoax http co ilbnslmdew',
#  'perhap put companion piec biggest arson denier',
#  'arsonist turn fire extinguish http co wrpe2yrlu',
#  'arsonist turn fire extinguish',
#  'bulli amp harass peopl disagre candid assess woman beat trump path',
#  'equival arsonist light fire rush hero put except fi http co xfebdyfvsa',
#  'got right arsonist chief australiaburn morrison even smugger amp smirkier usual bc clai',
#  'fke news none bush fire victoria lit arsonist',
#  'bhainsa nirmal district telangana stone pelter arsonist mob select target hindu properti v',
#  'call 185 arsonist',
#  'morbiu live vampir mean ok come name garamondo dead werewolf camandrak',
#  'one blog confirm voilenc link caa nrc protest bhainsa nirma',
#  'two dream one bad good hero second dream even rode 6 leg mystic http co nae63cjfz',
#  'happen bhainsa elect collud betweentr aimim arsonist mob bhainsaattack bhainsaburnt http co oleigmteci',
#  'mean sea sandwich',
#  'love see billionair talk climat chang lik http co t6knai9umn',
#  'australia burn peopl intent set bush fire creat panic http co ujugs9mne1',
#  'trump simpli polit arsonist requir crisi chao surviv crisi creat',
#  'tow truck cigarett butt toe tag bodi bag gunshot raindrop night citi burn sun w http co kzp4laixej',
#  'move quickli bush fire arsonist',
#  'trump simpli polit arsonist requir crisi chao surviv crisi',
#  'someon post discord agowijfaklw fjlkawefsa http co pyqymu2cgv',
#  'nationalist news anchor time question motiv davind singh dubiou offic',
#  'warren disappoint berni send peopl challeng berni say warren th',
#  'campaign would never attack support script direct campaign point',
#  'starwar skywalk saga lifetim oscarnom new hope 10 empir strike back 3 return jedi 5 phanto',
#  'let tell someth caus everi time post anyth polit get attack type crazi conservati',
#  'blink attack goal 2k rt 200 comment killthislov favechoreographi iheartaward http c',
#  'trump share horrif photo bloodi corps tweet trump share said question america support',
#  'two milit escort delhi polic offic possibl intend commit terrorist attack jan',
#  'one week watch democrat attack man stop church shoot mourn iranian terrorist blam',
#  'satan lazi attack send broke guy big ck life watch ladi',
#  'attack local journalist http co svuifchlja',
#  'rt fightextrem taliban claim respons roadsid bomb attack kandahar kill two http co 7ym9wsgkqp',
#  'use edit clip coordin viciou attack ill inform malici seem like apprais discuss india today',
#  'rt fightextrem embolden al shabab threaten strike american target around world day http co wafc8yvd5z',
#  'polic attack women student http co rkidl9ohga via',
#  'drone strike bird surprisingli common occur mani part world profession dronist sa http co aztjje5diz',
#  'interest question princip prevent loos defin principal http co yjredou6zk',
#  'ever accident send snap internet person heart attack',
#  'disingenu berni support lead attack warren suppos attack sander',
#  'afzal guru get hang death 2013 sinc gave refuge parliament attack terrorist claim',
#  'bori current bbc breakfast refer potu trump suggest reason uk',
#  'fake news media democrat partner work hard determin whether futur attack terr',
#  'genuin could agre abus harlow council 9 yr c http co 0iv4ngq2aq',
#  'anxieti attack tri look normal nobodi notic',
#  'rememb 2016 attack iaf base pathankot attack came offici car punjab polic sp salwi',
#  'moment take bucket full d6 sneak attack dnd dungeonsanddragon dnd5e http co qotzvhvliw',
#  'tri go school today everyth fine sit outsid classroom bc hand start http co jdbcnqrojh',
#  'dsp davind singh work jem terrorist money decad admit tortur afzal guru allegedli',
#  'break iranattack discov interview danish tv2 met soldier',
#  'troll launch mala fide campaign india today use edit clip co ordin viciou attack',
#  'welcom 2 oregon liber state u attack secur guard w machet use',
#  '8 07am local time two year ago today human error text alert escal us north korea tension lack',
#  'go repost hate speech presid today find vile would dress speaker muslim garb',
#  'along sever soldier danish sergeant wait sever hour bunker iraq iranian attac',
#  'orient islamophobia anti iran sentiment use attack peopl across polit aisl retweet',
#  'alert rais seriou question nation secur rais even uri attack enter',
#  'wheel within wheel davind singh kashmir senior cop held weapon two lashkar jaish men car',
#  'money websit pin tweet republican launch lil somthin beer futur attack tweet far govern lol everi thing like',
#  'love possess attack easili identifi foot soldier hell terrifi truth shall set free',
#  'six hour iran sent missil two militari base iraq danish govt defens forc knew',
#  'tire ppl alway tri attack cardi speak straight fact',
#  'kashmir dsp davind singh dramat arrest 2 milit creat big nation secur question india e',
#  'german hospit forc hire secur guard refuge physic attack nurs http co bkddlctdk5',
#  'inde incred 9 day attack jnu expos done media confess nation tv b',
#  'make mistak full attack 2020 elect new york time report russian',
#  'suddenli first layer come 9 rocket ton cannot describ never experienc anyth like',
#  'http co 2nigrcloeq eleph attack 400 sri lanka last year habit conveni choic',
#  'today attack anoth candid support rather record kind obnoxi',
#  '0bama still potu chicom would stolen presid cuz one administr would help taiwa',
#  'confirm attack databas uee stop sent back enemi http co bkubh95ka',
#  'statement follow conclus pensacola naval air station attack investig http co',
#  'end 2019 long await paper amp gorman lab show hydrogel inject attenu',
#  'plank row hellset attack ab http co 5diih4wbi',
#  'yehi hai wo sanghi ka room bachelor student jnu recal januari 5 attack leftist mob http co jhafgbcqyw vi',
#  'ok dont attack joke kslsk',
#  'accept respons express regret paid compens short ti http co ww071qrlwq',
#  'mob attack hindu burnt amp loot hous bhansia telangana aimim parti behind attack hindu http',
#  '21 saudi muslim aviat student investig connect decemb 2019 pensacola att',
#  'labour candid embarrass attempt attack nicola sturgeon http co aahcojuw0v',
#  'attack soldier surpris destruct greater would estim nearest r',
#  'gegenpress attack leav 1 cb back turn http co 92t1zcfjdh',
#  'zoom took ss feel attack fansit stay aliv http co xxtn2ht5kb',
#  'nyt expert find evid russian hack ukrainian ga compani engadget http co 1ukflo3iqh dan la ri http co y7gbe84m2j',
#  'person could theoret say trump attack femal nomine like hillari hear peopl',
#  'mayb could addict sure hard put need know what go http co rb6lyom7xh',
#  'white blood cell attack parasit http co o35owvtgnx',
#  'stone throw kill palestinian mother 8 recogn terror attack http co gjz3cqc7rl',
#  'iz one gonna disband said iz one resum fan worri http co zy16agqe42',
#  'tumn beta mumbai attack ke baad jha2 kabara tha kya tum sirf saboot mango http co ek6vwvmbpz',
#  'deepli troubl news violent attack individu properti bhainsa telangana action',
#  'us expel 21 saudi cadet terrorist attack base jihadist literatur 15 19 9 11 hijack',
#  'media think far right support america first trump agenda actual fiscal cons',
#  'particip counter fidayeen attack terrorist district polic line pulwahma 25 26 aug 2017 w',
#  'us militari base iraq day iran missil attack iranattack http co x2q8qixkvc via',
#  'feel attack http co prtvrimq6i',
#  'god go bless season devil attack',
#  'texa democrat congression candid violent attack red guard austin revolutionari comm',
#  'urgent need least 318 patriot american sign card support troop midnight missin',
#  'call racist britain attack racist ergo http co zha0maa05u',
#  'india attack islam terrorist leftist media silent hundr jihadist attack hindu loot amp burn 1',
#  'know ascend feel person attack',
#  'usasupportsterrorist 15 19 terrorist attack american septemb 11 fli plane world',
#  '20 hindu hous attack amp burn telangana peac commun stone pelt hous loot even polic perso',
#  'id love know actual differ type homophobia happen wilson http co mpxlgzunia',
#  'ft emperor got cloth biggest asset manag attack role climat chang sharehold put pressur blackr',
#  'peac mob attack peopl bhansia adilabad district telangana pelt stone loot hous burnt vehicl',
#  'spot fulli expect berni attack side tuesday demdeb',
#  'one ask feel cancer took figur cancer feel li',
#  'telangana experienc commun violenc last night stroke midnight almost 500 muslim attack hindu',
#  'presid trump gave save countri gave billionair lifestyl success busi popular',
#  'feel attack http co jg0vpnkiuk',
#  'omg feel attack bc true',
#  'snowflak trump hate idiot feel iran evil regim last week love',
#  'feel attack http co jy5jphzhey',
#  'attack iran reason breach sovereignti actual threatenin http co i1yosfx7bx',
#  'jessica yaniv attack outsid courthous respons get away f king crazi f ki',
#  'hard convers thing like dislik around critic p http co id35yjazog',
#  'liter attack http co cg9neeadxb',
#  'hindu vahini karyakarta hous burnt amp attack mim goonda bhansia arrest',
#  'kind illus berni consist attack media oth http co dlwviuo6nr',
#  'jansena chief cine star pawankalyan arriv vizag airport head kakinada parti men',
#  'muslim mob attack hindu famili telangana internet ban secular http co uqfkqe0zi4',
#  'gdp 6 yr low inflat 6 yr high nomin gdp 45 yr low unemploy 45 yr high petrol 80 oni',
#  'feel attack rn http co yxbcslffo4',
#  'utmost accept locust announc decim cs mwangi kiunjuri attack',
#  'congress demand home minist amit shah statement devind singh ask dsp connect parliament attack amp',
#  'thought get attack peopl say',
#  'son teenag girl arrest coupl attack centurion home http co wd9rbn13yv',
#  'use unblock spell keep hors run get attack',
#  'select midnight deadlin iran attack troop need know folk home back',
#  'abus tweet unbeliev call paedophil nonc attack ab',
#  'video iran exact date amp locat uncertain sourc say peopl identifi undercov agent amp attack',
#  'bhainsa 18 hous belong hindu burnt properti loot muslim mob local muslim youth enrag af',
#  'dear xrpcommun connect dot took heat ask account attack intentio',
#  'feel attack right http co x59fzgr1jb',
#  'congress attack modi call hindu jinnah use word like hindu jinnah hindu terror http co he10xfasva',
#  'terrorist attack peopl telangana smaller district bhainsa nirmal saw terror mob burn place tar',
#  'shhh get attack want dontent doyoung content',
#  'toxic by9ner dog start mess say emang semuanya salah by9 lagi omg im sorri never',
#  'solidar long time fierc warrior women right around globe attack',
#  'long lifetim survivingrkelli part 2 air earlier month one girlfriend went live faceboo',
#  'say playm best agenc tho agre suck manag promot artist least',
#  'islam jihadist mob attack hindu loot amp burnt 18 hous amp properti bhainsa town nirmal dist telangana la',
#  'rememb brie larson said need divers critic exact reason internet attack',
#  'clinton admit could kill bin laden 1998 chose http co ieaig9tthi know inact',
#  'stop short abvp question abvp cadr initi att http co avk3shs4uh',
#  '1st bia readi attack',
#  'read heard seen meghan racial attack b c im white white peopl ra http co dzccmlencg',
#  'polic record brutal arrest muslim man accrington even though muslim man volunt',
#  'defenseless peopl attack amp shot side secur forc amp plaincloth agent suddenli three bul',
#  'largscal violenc bhainsa dist nirmal telangana peac attack hindu loot amp burnt properti pelt stone',
#  'realli sick tire tri sidelin socialist like lp broad church',
#  'ran away got closer almost attack pick',
#  'isabella attack twitter',
#  'look comment 1500 protestor murder iranian tyrann govern http co g6mi1lxexz',
# ...
#  'afac0660 battl id need backup lvl 50 joya http co o4elq2iyi',
#  'sadli organ backward line ask david carr al http co ngwperj9cl',
#  '512b214f battl id need backup lvl 100 yggdrasil omega http co bvvsnpgz3w',
#  '1656abaf battl id need backup lvl 100 colossu omega http co yeonr59f9z',
#  'go add fals colour viru imag scream come get peopl begin reign bioterror wh',
#  'mexican border portal swine flu tb bioterror http co elw0scwnsr via',
#  'sir may tech quit use case bioterror attack http co pabur3cvum',
#  'realli know transmiss ebola one know certain ebola viru transmit',
#  'realli know transmiss ebola one know certain ebola viru transmitt http co nhai3yx6fb',
#  'human cull 38mins30sec http co p0xqtqvdef unfold http co egn7sdr116',
#  'human cull 38mins30sec http co p0xqtqvdef unfold http co egn7sdr116',
#  'courtesi mix peopl noth come america better life http co zepp4lzpna',
#  'maga5g livevil recommend read weak mind mossad 5g strain viral vengeanc pandem',
#  'lead deeper question defin arm info age defin conflict http co xmucojkkkk',
#  'int monarch motel day grayson punch face throw soda light fixtur voic http co x5s2c5x9bt',
#  'mexican border portal swine flu tb bioterror http co wtiqaknxqr via',
#  'dubiou efficaci ill effect vaccin scienc fact yet establish deni enforc vaccinatio',
#  'dubiou efficaci ill effect vaccin scienc fact yet establish deni enforc vacci http co ikaikqvgx',
#  'http co ovihlppihh interest jon rappoport',
#  'us mexico border portal tb swine flu bioterror headlin health http co 4wrisjs39m',
#  'us mexico border portal tb swine flu bioterror http co dvvyfako1l via',
#  'bioterror worst',
#  'us mexico border portal tb swine flu bioterror http co srrv6jpogc',
#  'us mexico border portal tb swine flu bioterror http co xv4mhvm5i via',
#  'us mexico border portal tb swine flu bioterror http co i64vgpn1ib via',
#  'push mass vaccin point toward stage bioterror event http co o10epcfrv6',
#  'push mass vaccin point toward stage bioterror event http co o10epcfrv6',
#  'bay area research tackl bioterror threat bioterror biodefens cbrn phep http co n5exzsqtau',
#  'push mass vaccin point toward stage bioterror event jon rappoport http co qctxok8cju',
#  'maga5g livevil recommend read weak mind mossad 5g strain viral vengeanc http co tm0jiqragb',
#  'push mass vaccin point toward stage bioterror event http co sn1z3ljnqq',
#  'want learn bioflash use variou configur deliv build protect sol http co dgerehrh4t',
#  'question biodef counter bioterror folk whether countri given viru sampl http co 9qq2ike3m1',
#  'al qaeda long sought expert bioterror nuke http co rjfdj0eipo',
#  '1 mullah lose support iran youth turn se http co rhprcwosrr',
#  'push mass vaccin point toward stage bioterror event http co a6euti4r23',
#  'buy tesla financ bioterror air filtrat',
#  'oper disclosur bioterror vaccin clarifi jon rappoport http co yb1bfs6clb',
#  'stage bioterror event http co iwftfxxugq',
#  'bioterror rare sick btwn give amp christma despit date vaccin http co zxvy3denti',
#  'push mass vaccin point toward stage bioterror event http co igw0jpawhx via report',
#  'rememb resid evil univers bioterror attack almost norm rescu oper http co ld2j8zphdl',
#  'push mass vaccin point toward stage bioterror event http co cnzbxd73ej',
#  'sound like anoth nudg toward mandatori vaccin http co 7yzkkpxs17',
#  'skipvaccin push mass vaccin point toward bioterror event read jon mega coll http co ennta5cqej',
#  'push vaccin point stage bioterror event http co wwvkqky1o2',
#  'interest articl definit someth consid http co 5kkg7k6nph',
#  'push vaccin point stage bioterror event http co wwvkqky1o2',
#  'push mass vaccin point toward stage bioterror event jon rappoport http co qctxok8cju http co huhp6mrgjn',
#  'vampiri awesom vampir thriller bite http co dxygraa6cj vampiri corsairadventur thriller va',
#  'hachi san88 leon clair fight bioterror busi day valu time spend tog',
#  'fight bioterror sir',
#  'hachi san88 leon clair fight bioterror busi day valu time spend http co hcjq3vatr2',
#  'threat plan commit bioterror activ spread diseas within commun http co bldezqcemr',
#  'either alarmist plan littl bioterror',
#  'nice call support bioterror',
#  'similarli lot differ disast includ epidem natur disast war bioterror http co nrp53sun5c',
#  'anti vax philosophi noth less bioterror urg take action encourag en',
#  'thank phil domest rule e g bioterror law overrid free trade rule http co fmnh415n3p',
#  'bit light read use http co ox9tltiv8k recal challen http co lluzy3ns8g',
#  'kid got influenza b read biggest outbreak 27 year http co e9jvq7yk20',
#  'strateg stockpil sound like case outbreak case bioterror threat',
#  'finish hahaha kinda like lol medj odd yung humor pero like bioterror center http co z0k4p6szjb',
#  'make bioterror sexi one dana idea',
#  'arrest bioterror',
#  'arrest bioterror',
#  'bioterror best anybodi ever question vaccin part fuck',
#  'http co il7cpxmsgx time sever secur challeng respect packag shoplift http co tyrfhnljay',
#  'sandwich bioterror',
#  'genocid bioterror',
#  'creat anti bioterror commiss',
#  'bioterror maldivesmeaslesoutbreak',
#  'anti vax philosophi noth less bioterror urg take action encourag http co sjrzznu9ln',
#  'show activ recent found bioterror manufactur diseas tin man android 2105 global organ would',
#  'hahdhufahanaelhi aalaathun balaa v bodu vaccin nudhinumake bioterror ge amaleh kamah kanda alhan jehijj miha http co 9qdxvzahnn',
#  'ga semua tapi ya cult model2 heaven gate jonestown atau aum shinrikyo bisa dengan mudah terpelatuk buat http co pbyilv05fc',
#  'feel turn 20pg paper bioterror amp civilliberti gradlif http',
#  'need classifi anti vax bioterror',
#  'bioterror caus arrest hundr arsonist set fire',
#  'god fault bioterror',
#  'bioterror biggest fear',
#  'awesom vampir thriller bite http co dxygraa6cj vampiri corsairadventur thriller vampir eld',
#  'cop bioterror sa polic appeal base technic mo http co epaskzuk71',
#  'somebodi need classifi anti vax bioterror',
#  'feel turn 20pg paper bioterror amp civilliberti gradlif http co fjaglfr7gn',
#  'kid get suspend bioterror blood get everywher actual',
#  'say sooner name work bsaa fend http co yx2od7xqrh',
#  'awesom vampir thriller bite http co dxygrari0t vampiri corsairadventur thriller vampir eld',
#  'sandwich bioterror',
#  'chri redfield bioterror expert',
#  'respons un human right ambassador time world face huge human r http co gfaoaxdspu',
#  'whoever come unscath toximu prime',
#  'martin tebbutt farm bilpin complet char gosper mountain blaze rip area dec',
#  'blaze destroy build louisiana apart complex http co guschprrtw http co eh5n0xzc0o',
#  'upgrad blaze versa x',
#  'blaze weird person steak overr',
#  'two fight protect right reviv eu amp enlighten valu altern campaign rejoin',
#  'trussel trust support 1 200 food bank last year provid food bank network 1 3m fu',
#  'findstolenmollywn6 seen area pleas black amp white black right side white',
#  'work next one lead govern advisor e bazany offer throw bottl mu',
#  'definit skyf slot',
#  'blaze http co dzkqk4g9pb',
#  'blaze buff kill',
#  '420 blaze',
#  'definit major interview let start brexitjohnson releasetherussiareport',
#  'know sir arthur conan doyl surgeon train ophthalmolog refer john weiss instr',
#  'enough dhawan let young gun blaze',
#  'know sir arthur conan doyl surgeon train ophthalmolog refer john weiss http co 3k9hd5gus0',
#  'blaze',
#  'hack gate etern blaze',
#  'blaze giant',
#  'fire blaze http co t4fakjikl0',
#  '200105 golden disc award carol e555558 btsxgda jhope rm http co yj8vwezu9d',
#  '200105 golden disc award brillant mon btsxgda rm jhope http co mdglujyeqi',
#  'mnasumbua blaze bure tu haha http co 7w8x4cqomx',
#  'hire everi larg water carri aircraft world help put mega blaze span vic http co dhqtlqrlho',
#  'amaz stori air moment mega blaze nsw victorian border next lo',
#  'tbh idea chamoru look like seen whitest dar http co cyn87lv1yg',
#  'blaze chronic w u',
#  'gotta carri 80 logbook 4 post like nevermind brace bc stronk shit pejaba http co zo3nopjprh',
#  'alic bleed blood red bleed blue atol pee yellow blaze yellow',
#  'yang simpli chuckl littl stare fluster fusion found kefla even cuter http co ypgao2rqll',
#  'blaze maywardloveforr pushawardsmayward',
#  '2017 l blaze squad 2018 danni dyer dad 2019 tyson furi brother 2020 lewi capaldi ex lov',
#  'star dont dissapear keep blaze http co 6g642pn0bq',
#  '1 602 mile teach gun blaze cat fur http co gjitivvopa',
#  'anoth vers oscil strong enough still swell water evanesc http co zpmpuqqtx4',
#  'munni need vent come dm',
#  'benchmark updat alert realiz fastifi gql graphql jit default turn blaze',
#  'see vic back tl get blaze around happi 2020 leadership',
#  'see vic back tl get blaze around happi 2020 leadership',
#  'margaret cavendish english philosoph author born 1623 first woman attend meet',
#  'kartikgoenka flame blaze volcano readi erupt man whose silenc mistaken weak mohsink',
#  'kathniel2020 bring us tang mahal kathniel record break movi thou come back primetim',
#  'hpe rapid setup softwar guid custom system instal setup configur new server http co 1hoysky5ar',
#  'come amp checkout blaze websit full differ girl twerk free bootytub twerk http co ap5zsgx0mc',
#  'bunch flower within heart bloom toward blaze sun fragranc sweeter fine wine scarecrow drownin',
#  'boob even matter ladi lung import caus blaze mad kush http co g0jivsmkwd',
#  'shadow keep grow blaze light',
#  'obsnewrev motherwel girlhood deborah orr review fit legaci blaze talent http co sa2qokkdv9',
#  'congratul blaze new trail',
#  'blaze heat unstabl foot type condit stifl lesser men terrain meaningless st http co 2e0nx0meaz',
#  'work lgbt inclus educ scotland ensur gener lgbt young peopl ever fe',
#  'pauli got advanc payment handler come gun blaze',
#  'ok beat blaze bull sekiro could think rage bull',
#  'cue blaze http co yutavvjakn',
#  'nazo sasitheni touch indian boy come gun blaze cat prevail',
#  'blaze virtu 2018 http co zuqjgmg47c',
#  'blaze saddl 45 movi get made today http co jmf8s1vztj newsandpolit via',
#  'twinkl twinkl littl star wonder world high like diamond sky http co wt8fjqhnme',
#  'madelin kahn lili von shtupp outrag comedi classic blaze saddl 1974 direct mel brook let f',
#  'announc bengal 2020 south squad wr group edward underr johnson enorm jen aggress ai',
#  'fear public toilet complet vanish im person absolut rip train station toilet gun blaze',
#  'one week go qodebrisban highlight incl futur smartciti w brisban cdo quantum comput',
#  'happi birthday sir inde star nurs commun keep blaze high http co iajdtlsnzw',
#  'love divers bodi posit cast loveisland2020 itv bl http co flndchd3i3',
#  'eat ice cream underneath blaze hot sun',
#  'interview comedi horror anim screen',
#  'shot one two colt aim one left hand trent could pull trigger remington',
#  'shot one two colt aim one left hand trent could pull trigger rem http co asyxjxnfd0',
#  'list goe folk stabl platform http co 9c0icq3vk7',
#  'swear dear mother grave well would one goin shoot trent http co bfdjeol3px',
#  'hangyul nae gaseumsog blaze dip http co b4azpv6mmc',
#  'trent reach right hand behind back retriev remington 44 stash away waistband hi http co 2pmohifxuq',
#  'fair call wc done wc iyer blaze form 4',
#  'steve roustabout colston like sent brother straight hell neither grant wesley b http co owjeveq7ho',
#  'blaze green green monday telegram 2 3 thank enough god know th',
#  'jenni look said bass need need go tecumseh kill get bass http co 9dzgbtdopw',
#  'excit share long await next js notion static gener blog exampl tech http co hvclcvuo',
#  'got deck card shirt pocket boy want play drinkin game folk call red bla http co tynwgmrref',
#  'nowplay jimpster blaze water http co xexu21nqxj',
#  'keep blaze',
#  'kindl need new western fill need one western like bass reev blaze furi http co yaahi8mxfw',
#  'name life phantom tsukushi night red moon blaze beauti sekainoowari',
#  'angri women go gmb gun blaze mean take http co hurtuyxevu',
#  'grizzli maze http co uaoe62avnx mobil user http co gvhozmngn7 blaze fast advertis http co jsmglj6xl5',
#  'eagl soar blaze sun show strength truli belong top',
#  'scorch earth peopl parallel platform enter ado movement',
#  'blaze saddl',
#  'od team certainli trail blaze fabul team great thing someon dream job http',
#  'fun fact thumb short circuit let peopl know okay head cannon',
#  'truth put concentr camp cage wall noth http co detzsrfaz',
#  'bleed',
#  'hmm scratch ear bleed',
#  'make sound vegan societi provid certi',
#  'would know help victim knife crime download new app learn life save bleed control techniqu',
#  'play mhw friend friend jerki curs bleed friend yeah wish',
#  'doctor help wound bleed death pleas stem bleed get bandag ah',
#  'bleed heart artist let get away murder let hammer today trial',
#  'ask prayer daughter pleas took think flu intens care',
#  'chanc stop bleed debat tomorrow night see right thing',
#  'imagin support biden fuck biden littl girl http co kzijbcoz',
#  'sometim want dio fuck eviscer make sweet sweet love open fester wound lay b http co 5hx5mxpds8',
#  'presid unit state make countri live f king hell tri stay posit elect 2020',
#  'ghanaian women would stab back ask bleed',
#  'live cervic cancer bleed pain sex symptom diseas dr kwaku asah opoku obstetr http co bgg5mbhmph',
#  'iran video show woman protest shot bleed street http co prlgy7xiup via',
#  'stop ur bleed noth ever stop ur leav',
#  'live cervic cancer bleed menopaus sign diseas dr kwaku ansah opoku obstetrician amp g http co csb6vh7pfu',
#  'mum die cervic cancer deni smear test despit bleed sex http co kghzin5cs1',
#  'freedom movement bleed central souther europ dri http co idoon1ylaz',
#  'u tweet im listen bleed love',
#  'well done bori statement bleed obviou bbc news harri meghan royal famili http co erhvoic7a3',
#  'bleed heart music video come soon vicscov bleedingheart musicvideo rocknrol gothrock cali http co cly1g7jcxk',
#  'bleed madra',
#  'refer bleed heart liber influenc ideolog rousseau made snort http co gzy2x2djzb',
#  'glen say bleed obviou label neg pessimist doomer tell godd http co lgjxuglyvr',
#  'post malon hollywood bleed slow perfect http co csl6elzqpi via',
#  'icymi silenc surround revel mueller collabor cia tortur program new articl guantanamo',
#  'confus actual posit critic idea put tampon machin',
#  'peopl go bankrupt medic debt 12k year minu vat put dent let http co i31t5kg5l',
#  'nose bleed wtf',
#  'jojo outcom pictur',
#  'scmp ocean park bailout plan hong kong govern help fund attract reviv stop bleed',
#  'anfield actual found roma scar lightli bandag got open http co 6n2b90imv7',
#  'thank think normal like http co rfdutzxzyx',
#  '100th time bandag around head mean whole skull broken bandag goe aroun http co ue9ika2nra',
#  'nevermind nose start bleed',
#  'imagin shot govern want freedom hard imagin right mean america',
#  'forgot lip balm hold sleep babi lip dri crack bleed',
#  'sad sorri state indian economi govern prioriti see saffron color indian map b http co 76y13dtrhw',
#  'intraven oxytocin reduc sever bleed vagin deliveri nihr signal http co c1lumroemd',
#  'wont tast like die fine like rather die http co x0lyw9qqx',
#  'halfway januari financ look pocket still bleed time give fina',
#  'parent child scream airport understand children alot handl ear bleed',
#  'oh god fuck eye ear liter bleed watch http co hofazd4oe8',
#  'cat went crazi bleed',
#  'saw report women increas menstruat bleed http co wrw0zeyeyp',
#  'floral note bleed heart flower fresh peoni petal lust madlov perfumehol http',
#  'wonder rick ricki dude bleed',
#  'hope mind busi republican unless street iranian prote',
#  'mcr stan kid primari school bleed put cut mouth stop',
#  'much histori submerg mucki detail clariti much death bleed yet v http co nemgmbmcxm',
#  'kinda want watch',
#  'ghanaian women would stab back ask bleed http co yurswbwrxk',
#  'context major bleed cat combat applic tourniquet say cat tourniquet exampl redundan',
#  'weird ppl w vagina liter spent day bleed sever cramp nausea headach muscl ach',
#  'mum die cervic cancer deni smear test despit bleed sex mirror onlin http co mbkty8o11a',
#  'seven head snake u call bleed like open scar',
#  ...]

# %%
onehot_rep = [one_hot(words, voc_size) for words in corpus]
print(onehot_rep)
# Out:
# [[1867, 4073, 542, 2389, 2589, 3666, 4830, 4637, 4637, 4179, 3993, 732], [2389, 1338, 1040, 3329, 542, 317, 709, 2482, 1683, 922, 90, 995, 317, 2072, 4765], [4548, 3993, 3583, 732, 2431, 143, 3045, 2878], [4548, 3993, 3583, 732, 2431, 143, 3045, 169, 143, 3045, 1662], [4832, 1488, 88, 1476, 3694, 3519, 2113, 892, 449, 3993, 4168, 732, 1259, 143, 3045, 4713], [136, 4946, 2894, 4127, 3409, 3779, 343, 2455, 4127, 732, 3546, 4127, 1229, 3717, 3126], [1695, 4637, 3993, 732, 378, 1542, 1012, 3638, 4703, 4395, 126, 2190, 4869, 143, 3045, 3465], [4345, 535, 4978, 1191, 1542, 3993, 732, 1716, 1819, 535, 4191, 1200, 1854, 2434, 2111, 498], [4525, 53, 2700, 3336, 1542, 553, 3140, 3993, 2293, 732, 254, 132, 1196, 143, 3045, 2983], [1070, 3498, 3814, 1471, 3697, 732, 1388, 3206, 1750, 1750, 143, 3045, 3369], [298, 4895, 2453, 2091, 4869, 3606, 3228, 4637, 1012, 1550, 3606, 3443], [343, 2455, 3972, 4395, 4368, 1639, 1007, 4866, 4791, 2142, 3674, 2307, 143, 3045, 354], [3899, 2979, 3993, 4127, 4978, 4565, 2542, 3066, 1641, 386, 4127, 732, 4573, 2689, 1930, 2896, 4127, 4978], [189, 2077, 4073, 4648, 2766, 3257, 1513, 126, 4181, 4978, 3786], [2437, 3993, 2087, 4786, 732, 4195, 143, 3045, 3419], [298, 4895, 2453, 2091, 4869, 3606, 3228, 4637, 1012, 1550, 3606, 143, 3045, 2690], [1393, 2403, 3066, 3033, 1496, 836, 732, 247, 143, 3045, 3160], [3545, 3993, 4168, 732, 967, 2565, 819, 4306, 494, 143, 3045, 3455], [986, 1408, 732, 1360, 430, 4791, 143, 3045, 4513, 143, 3045, 2617], [743, 1812, 3993, 4637, 732, 1438, 2333, 90, 3203, 4496, 478, 4661, 4562, 1458], [4869, 250, 2904, 3816, 4525, 4715, 1057, 375, 1542, 3292, 3993, 732, 1031], [4037, 732, 2119, 3601, 2468, 1430, 3891, 4082, 1461, 1908, 3891, 3611], [2982, 969, 3628, 4120, 3656, 376, 3656, 2531, 143, 3045, 3101], [244, 4037, 3517, 4196, 3993, 732, 4607], [3379, 541, 4037, 1734, 910, 4816, 940, 3179, 4816, 4645, 143, 3045, 4608], [2142, 3601, 3630, 1152, 371, 3656, 660, 1965, 3768, 145, 3993, 732], [4548, 299, 3338, 3621, 4692, 4101, 4328, 709, 3076, 4715, 3993, 732, 1641, 1461, 3015, 2142], [4548, 3625, 4739, 2259, 1134, 3993, 732, 1887, 1759, 2278, 3970, 278], [3293, 4162, 1496], [1463, 1291, 3993, 2071, 732], [1470, 4124, 59, 4866, 452, 376, 4715, 2175, 3993, 1798, 782, 3611, 732], [1470, 4124, 59, 4866, 452, 376, 4715, 2175, 3993, 1798, 782, 3611, 732, 143, 3045, 4322], [404, 19, 654, 3361, 3993, 732, 4372, 4637, 4147, 143, 3045, 474], [88, 3521, 2830, 707, 131, 346, 3079, 4811, 4774, 4057, 143, 3045, 4273], [3378, 3957, 80, 4270, 3644, 4111, 1864, 4564, 798, 1436, 1502, 3964, 3686, 143, 3045, 2663], [2334, 477, 700, 2700, 733, 4202, 2049, 4373, 2057, 4202, 2049, 1432, 1420, 35, 4360, 3410, 143, 3045, 3111], [3873, 1107, 1159, 3154, 743, 3972, 749, 43, 391, 2856, 2195, 2186, 4676, 3133, 734], [2561, 15, 1002, 3546, 3286, 2623, 4373, 1390, 2645, 143, 3045, 931], [2153, 3220, 2479, 168, 3821, 3302, 2856, 3079, 1031, 772, 1044], [4688, 718, 2318, 616, 3379, 2808, 4067, 3811, 1319, 143, 3045, 3908], [799, 4188, 2403, 2072, 2552, 4620, 639, 2199, 4989, 254], [4252, 4609, 836, 707, 2856], [1200, 4013, 4746, 719, 851, 3261, 3827, 874, 2856, 143, 3045, 220], [3253, 3722, 4830, 3069, 1809, 2570, 1608, 686, 4648, 1346, 2426], [234, 4710, 1616, 1390, 1858, 1036, 2521, 3079, 4007, 3786, 3710, 3734, 995, 2856], [3237, 4195, 4898, 1692, 3220, 2880, 1371, 3909, 979, 2338, 260, 2394, 4195], [3324, 3583, 2732, 995, 4111, 3674, 4586, 1054, 2545, 2870, 964, 3015], [525, 4177, 4437, 949, 2856, 3898, 4484, 836, 2717, 3771, 4503, 4095], [3428, 2714, 4548, 3583, 2856, 143, 3045, 940], [3082, 4110, 1048, 22, 4524, 3229, 2031, 1261, 4791, 3349, 2856], [3771, 3625, 525, 1765, 3035, 2856, 973, 4179, 1465], [1018, 2074, 1775, 2856, 143, 3045, 303], [1553, 311, 3741, 2442, 2455, 4740, 2561, 4531, 2859, 2856, 143, 3045, 3239], [1150, 2856, 145, 3993, 1515, 3506, 304, 918, 1367, 2750, 4394, 4059, 143, 3045, 1569], [1390, 4484, 2082, 4040, 2856, 537, 2082, 760, 4564, 4039, 3554, 379], [1816, 4255, 2856, 4958, 3737, 4394 ...

# %%
corpus[0]
# Out:
# 'commun violenc bhainsa telangana stone pelt muslim hous hous vehicl set ablaz'

# %%
onehot_rep[0]
# Out:
# [1867, 4073, 542, 2389, 2589, 3666, 4830, 4637, 4637, 4179, 3993, 732]

# %% [markdown]
# ### Embeddeding Representation

# %%
sent_length = 20
embedded_docs = pad_sequences(onehot_rep, padding='post', maxlen = sent_length)
print(embedded_docs)
# Out:
# [[1867 4073  542 ...    0    0    0]
#  [2389 1338 1040 ...    0    0    0]
#  [4548 3993 3583 ...    0    0    0]
#  ...
#  [4575  931 3806 ...    0    0    0]
#  [3655 3227 2323 ...    0    0    0]
#  [ 281 4348 1617 ...    0    0    0]]

# %%
embedded_docs[0]
# Out:
# array([1867, 4073,  542, 2389, 2589, 3666, 4830, 4637, 4637, 4179, 3993,
#         732,    0,    0,    0,    0,    0,    0,    0,    0], dtype=int32)

# %%
corpus[5]
# Out:
# 'child chines tweet would gone viral social media would ablaz snl would made racist j'

# %%
embedded_docs[5]
# Out:
# array([ 136, 4946, 2894, 4127, 3409, 3779,  343, 2455, 4127,  732, 3546,
#        4127, 1229, 3717, 3126,    0,    0,    0,    0,    0], dtype=int32)

# %% [markdown]
# ### Model Building
# ### Bidirectional LSTM

# %%
embedding_vector_features = 40

# %%
model = Sequential()
model.add(Embedding(voc_size, embedding_vector_features))
model.build(input_shape=(None, sent_length))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(100)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid',kernel_regularizer=l2(0.001)))
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_11 (Embedding)        │ (None, 20, 40)         │       200,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 20, 40)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 200)            │       112,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 200)            │           800 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │           201 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 313,801 (1.20 MB)
#  Trainable params: 313,401 (1.20 MB)
#  Non-trainable params: 400 (1.56 KB)

# %%
len(embedded_docs), y.shape
# Out:
# (11370, (11370,))

# %%
X_final = np.array(embedded_docs).astype('int')
y_final = np.array(y).astype('int')

# %%
X_final.shape, y_final.shape
# Out:
# ((11370, 20), (11370,))

# %% [markdown]
# ### Model Building

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping

# %%
X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, test_size=0.2, random_state=42)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True, mode='min', verbose=1)

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights = {i: weights[i] for i in range(len(weights))}
print("Class Weights:", class_weights)
# Out:
# Class Weights: {0: np.float64(0.6164272160477094), 1: np.float64(2.647264260768335)}

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=20, batch_size=64, class_weight=class_weights, callbacks=[early_stop])
# Out:
# Epoch 1/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.6050 - loss: 0.6418 - val_accuracy: 0.8259 - val_loss: 0.5218
# Epoch 2/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8361 - loss: 0.3633 - val_accuracy: 0.8259 - val_loss: 0.4120
# Epoch 3/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8905 - loss: 0.2732 - val_accuracy: 0.8531 - val_loss: 0.3289
# Epoch 4/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9185 - loss: 0.1939 - val_accuracy: 0.8615 - val_loss: 0.3474
# Epoch 5/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9317 - loss: 0.1634 - val_accuracy: 0.8843 - val_loss: 0.3196
# Epoch 6/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9433 - loss: 0.1362 - val_accuracy: 0.8681 - val_loss: 0.3882
# Epoch 7/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9579 - loss: 0.1093 - val_accuracy: 0.8852 - val_loss: 0.4506
# Epoch 8/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9707 - loss: 0.0824 - val_accuracy: 0.8813 - val_loss: 0.5189
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 5.

# %%
model.save("disaster_model.keras")

# %%
from sklearn.metrics import precision_recall_curve, f1_score

y_pred_prob = model.predict(X_train)
precisions, recalls, thresholds = precision_recall_curve(y_train, y_pred_prob)

f1_scores = 2 * (precisions * recalls) / (precisions + recalls)
best_threshold = thresholds[np.argmax(f1_scores)]

print("Best threshold based on F1:", best_threshold)
# Out:
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Best threshold based on F1: 0.46997342

# %%
y_pred = (model.predict(X_test) > 0.31).astype(int)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8689533861037819

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1697,  181],
#        [ 117,  279]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92      1878
#            1       0.61      0.70      0.65       396
#
#     accuracy                           0.87      2274
#    macro avg       0.77      0.80      0.79      2274
# weighted avg       0.88      0.87      0.87      2274

# %%
from tensorflow.keras.models import load_model
from nltk.stem.porter import PorterStemmer

# Ensure these are consistent with your training setup
vocab_size = 5000
sent_length = 20
model_path = '/content/disaster_model.keras'  # Save your trained model as this

# Load the trained model
model = load_model(model_path)

# Initialize stemmer
ps = PorterStemmer()

# Predict Function
def predict_disaster_tweet(tweet: str):
    review = re.sub('[^a-zA-Z0-9]', ' ', tweet)
    review = review.lower()
    review = review.split()

    review = [ps.stem(word) for word in review if word not in stopwords.words('english')]
    review = ' '.join(review)

    encoded = one_hot(review, vocab_size)
    padded = pad_sequences([encoded], maxlen=sent_length, padding='post')

    #Predict
    prediction = model.predict(padded)[0][0]
    label = "🚨 Disaster Tweet" if prediction >= 0.31 else "✅ Not a Disaster Tweet"

    return label, prediction

example_tweet = "Massive earthquake just shook the entire city. Buildings are down!"
result, score = predict_disaster_tweet(example_tweet)
print(f"{result} (Confidence: {score:.2f})")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 🚨 Disaster Tweet (Confidence: 0.55)

# %%
# from tensorflow.keras.preprocessing.text import Tokenizer
# import pickle

# # Load your original dataframe
# import pandas as pd
# df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/tweets.csv')  # Use your exact file path

# # Fit tokenizer
# tokenizer = Tokenizer(num_words=5000, oov_token="<OOV>")
# tokenizer.fit_on_texts(df['text'].astype(str))

# # Save tokenizer to file
# with open('tokenizer.pkl', 'wb') as f:
#     pickle.dump(tokenizer, f)

# %% [markdown]
# ### Model Building
# ### Stacked LSTM

# %%
stacked_lstm_model = Sequential()
stacked_lstm_model.add(Embedding(10000, 32))
stacked_lstm_model.build(input_shape=(None, 100))
stacked_lstm_model.add(Dropout(0.5))
stacked_lstm_model.add(LSTM(100, return_sequences=True))  # First LSTM layer
stacked_lstm_model.add(LSTM(100))                         # Second LSTM layer (stacked)
stacked_lstm_model.add(Dropout(0.5))
stacked_lstm_model.add(Dense(1, activation='sigmoid', kernel_regularizer=l2(0.001)))
stacked_lstm_model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# %%
stacked_lstm_model.summary()
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_13 (Embedding)        │ (None, 100, 32)        │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 100, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_24 (LSTM)                  │ (None, 100, 100)       │        53,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_25 (LSTM)                  │ (None, 100)            │        80,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 453,701 (1.73 MB)
#  Trainable params: 453,701 (1.73 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights = {i: weights[i] for i in range(len(weights))}
print("Class Weights:", class_weights)
# Out:
# Class Weights: {0: np.float64(0.6164272160477094), 1: np.float64(2.647264260768335)}

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=1, restore_best_weights=True, mode='min', verbose=1)

# %%
history2 = stacked_lstm_model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=20, batch_size=64, class_weight=class_weights, callbacks=[early_stop])
# Out:
# Epoch 1/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7203 - loss: 0.6402 - val_accuracy: 0.8162 - val_loss: 0.4250
# Epoch 2/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8606 - loss: 0.3737 - val_accuracy: 0.8483 - val_loss: 0.3838
# Epoch 3/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8929 - loss: 0.2928 - val_accuracy: 0.8505 - val_loss: 0.4216
# Epoch 3: early stopping
# Restoring model weights from the end of the best epoch: 2.

# %%
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])

# %%
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])

# %%
from sklearn.metrics import precision_recall_curve, f1_score

y_pred_prob = model.predict(X_train)
precisions, recalls, thresholds = precision_recall_curve(y_train, y_pred_prob)

f1_scores = 2 * (precisions * recalls) / (precisions + recalls)
best_threshold = thresholds[np.argmax(f1_scores)]

print("Best threshold based on F1:", best_threshold)
# Out:
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Best threshold based on F1: 0.46997342

# %%
y_pred2 = (model.predict(X_test) > 0.6).astype(int)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
accuracy_score(y_test, y_pred2)
# Out:
# 0.8896218117854002

# %%
confusion_matrix(y_test, y_pred2)
# Out:
# array([[1800,   78],
#        [ 173,  223]])

# %%
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93      1878
#            1       0.74      0.56      0.64       396
#
#     accuracy                           0.89      2274
#    macro avg       0.83      0.76      0.79      2274
# weighted avg       0.88      0.89      0.88      2274
